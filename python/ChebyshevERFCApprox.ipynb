# %%
from mpmath import *
import sys
mp.dps = 18; mp.pretty = True

def erfcApr(x):
  z = abs(x);
  t = 1 / (1 + z / 2);
  r = t * exp(-z * z - mpf(1.26551223) + t * (mpf(1.00002368) +
            t * (mpf(0.37409196) + t * (mpf(0.09678418) + t * (mpf(-0.18628806) +
            t * (mpf(0.27886807) + t * (mpf(-1.13520398) + t * (mpf(1.48851587) +
            t * (mpf(-0.82215223) + t * mpf(0.17087277))))))))))
  return r if x >= 0 else 2 - r;

# %%
def findMinN(start, end, maxErr):
  n = 1
  apr_poly,apr_err = chebyfit(erfcApr, [start, end], n, error=True)
  while(apr_err>maxErr):
    n += 1
    apr_poly,apr_err = chebyfit(erfcApr, [start, end], n, error=True)
  return apr_poly,apr_err,n

# %%
def findIntervals(start, end, maxErr, maxPolyDeg, prec=mpf("0.01")):
  maxREnd = start
  l = start
  r = end
  while(l<=r-prec):
    mid = (l+r)/2
    poly,err,cheb_deg = findMinN(start,mid, maxErr)
    if (cheb_deg<=maxPolyDeg):
      maxREnd = mid
      l = mid
    else:
      r = mid
  if(maxREnd>=end-prec):
    # We covered the whole interval
    return [(start, end, (err, poly))]
  else:
    return [(start, maxREnd, (err, poly))] + findIntervals(maxREnd, end, maxErr, maxPolyDeg, prec)

# %%
maxEr = mpf("1e-8")
a = mpf("0")
b = mpf("6.24")

for max_poly_deg in range(26,2,-1):
  intervals = findIntervals(a,b,maxEr,max_poly_deg,prec=mpf("0.0000001"))
  print(f"Max degree: {max_poly_deg}, intervals number: {len(intervals)}, intervals: {intervals}")
# Out:
# Max degree: 26, intervals number: 1, intervals: [(0.0, 6.24, (7.07136102279702359e-9, [2.35303852350415968e-13, -1.79650021036665447e-11, 6.41316135572316863e-10, -1.42094613449361125e-8, 2.18716355498748383e-7, -2.47993940912161502e-6, 0.0000214278231519267562, -0.000143941783670529834, 0.000760069616635675832, -0.00316928021138466261, 0.0104342602259019238, -0.0270564094427213377, 0.0552430572620798423, -0.0897983138836376996, 0.119683046624680173, -0.132871235648176518, 0.110209110981269878, -0.0499497698900735707, 0.0426551089891773893, -0.131126798295549522, 0.00571673927428194877, 0.374941210664231681, 0.000139075191135467865, -1.12838589774345848, 1.00000002794982858]))]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-80db718b54fa> in <cell line: 5>()
#       4
#       5 for max_poly_deg in range(26,2,-1):
# ----> 6   intervals = findIntervals(a,b,maxEr,max_poly_deg,prec=mpf("0.0000001"))
#       7   print(f"Max degree: {max_poly_deg}, intervals number: {len(intervals)}, intervals: {intervals}")
#
# <ipython-input-3-981a60a1404c> in findIntervals(start, end, maxErr, maxPolyDeg, prec)
#       5   while(l<=r-prec):
#       6     mid = (l+r)/2
# ----> 7     poly,err,cheb_deg = findMinN(start,mid, maxErr)
#       8     if (cheb_deg<=maxPolyDeg):
#       9       maxREnd = mid
#
# <ipython-input-2-850a87ad68ca> in findMinN(start, end, maxErr)
#       4   while(apr_err>maxErr):
#       5     n += 1
# ----> 6     apr_poly,apr_err = chebyfit(erfcApr, [start, end], n, error=True)
#       7   return apr_poly,apr_err,n
#
# /usr/local/lib/python3.10/dist-packages/mpmath/calculus/approximation.py in chebyfit(ctx, f, interval, N, error)
#     116     try:
#     117         ctx.prec = orig + int(N**0.5) + 20
# --> 118         c = [chebcoeff(ctx,f,a,b,k,N) for k in range(N)]
#     119         d = [ctx.zero] * N
#     120         d[0] = -c[0]/2
#
# /usr/local/lib/python3.10/dist-packages/mpmath/calculus/approximation.py in <listcomp>(.0)
#     116     try:
#     117         ctx.prec = orig + int(N**0.5) + 20
# --> 118         c = [chebcoeff(ctx,f,a,b,k,N) for k in range(N)]
#     119         d = [ctx.zero] * N
#     120         d[0] = -c[0]/2
#
# /usr/local/lib/python3.10/dist-packages/mpmath/calculus/approximation.py in chebcoeff(ctx, f, a, b, j, N)
#      20     for k in range(1, N+1):
#      21         t = ctx.cospi((k-h)/N)
# ---> 22         s += f(t*(b-a)*h + (b+a)*h) * ctx.cospi(j*(k-h)/N)
#      23     return 2*s/N
#      24
#
# /usr/local/lib/python3.10/dist-packages/mpmath/ctx_mp_python.py in f(x, **kwargs)
#     998             if hasattr(x, '_mpf_'):
#     999                 try:
# -> 1000                     return ctx.make_mpf(mpf_f(x._mpf_, prec, rounding))
#    1001                 except ComplexResult:
#    1002                     # Handle propagation to complex
#
# /usr/local/lib/python3.10/dist-packages/mpmath/libmp/libelefun.py in mpf_cos_pi(x, prec, rnd)
#    1380 def mpf_tan(x, prec, rnd=round_fast): return mpf_cos_sin(x, prec, rnd, 3)
#    1381 def mpf_cos_sin_pi(x, prec, rnd=round_fast): return mpf_cos_sin(x, prec, rnd, 0, 1)
# -> 1382 def mpf_cos_pi(x, prec, rnd=round_fast): return mpf_cos_sin(x, prec, rnd, 1, 1)
#    1383 def mpf_sin_pi(x, prec, rnd=round_fast): return mpf_cos_sin(x, prec, rnd, 2, 1)
#    1384 def mpf_cosh(x, prec, rnd=round_fast): return mpf_cosh_sinh(x, prec, rnd)[0]
#
# /usr/local/lib/python3.10/dist-packages/mpmath/libmp/libelefun.py in mpf_cos_sin(x, prec, rnd, which, pi)
#    1358     else:
#    1359         t, n, wp = mod_pi2(man, exp, mag, wp)
# -> 1360     c, s = cos_sin_basecase(t, wp)
#    1361     m = n & 3
#    1362     if   m == 1: c, s = -s, c
#
# KeyboardInterrupt:

# %%
a = mpf("0")
b = mpf("6.24")
maxEr = mpf("1e-9")
max_poly_deg = 5
intervals = findIntervals(a,b,maxEr,max_poly_deg,prec=mpf("0.0000001"))
ends = []
print(f"Max degree: {max_poly_deg}, intervals number: {len(intervals)}")
for i in range(len(intervals)):
  start, end, (err, poly) = intervals[i]
  print('old',poly)
  poly = [int(mpf('1e18')*poly[j]) for j in range(len(poly))]
  print('new',poly)
  int_end = int(mpf('1e18')*end)
  intervals[i] = (start, int_end, (err, poly))
  ends.append(int_end)

  print(f"Interval: [{start}, {end}]. Error: {err}. Poly: \n", \
   *[f"poly{i}[{j}] = {poly[j]};\n" for j in range(len(poly))])
# Out:
# Max degree: 5, intervals number: 29
# old [-0.124620041230776014, 0.00594883826956300222, 0.374802697318461983, 0.000151951361675853106, -1.12838630244934578, 1.00000002999258644]
# new [-124620041230776013, 5948838269563002, 374802697318461983, 151951361675853, -1128386302449345780, 1000000029992586435]
# Interval: [0.0, 0.0835052776336669922]. Error: 7.36106893691432508e-12. Poly:
#  poly0[0] = -124620041230776013;
#  poly0[1] = 5948838269563002;
#  poly0[2] = 374802697318461983;
#  poly0[3] = 151951361675853;
#  poly0[4] = -1128386302449345780;
#  poly0[5] = 1000000029992586435;
#
# old [-0.0689735423028576442, 0.392951190781528111, -0.00203891235999828982, -1.12825526344796592, 0.999996933043385613]
# new [-68973542302857644, 392951190781528110, -2038912359998289, -1128255263447965918, 999996933043385612]
# Interval: [0.0835052776336669922, 0.169659591110680736]. Error: 9.99996541155601201e-10. Poly:
#  poly1[0] = -68973542302857644;
#  poly1[1] = 392951190781528110;
#  poly1[2] = -2038912359998289;
#  poly1[3] = -1128255263447965918;
#  poly1[4] = 999996933043385612;
#
# old [-0.111918901176566153, 0.421997236468903653, -0.0095087616615832827, -1.12738991935200946, 0.999958866368956909]
# new [-111918901176566152, 421997236468903652, -9508761661583282, -1127389919352009459, 999958866368956909]
# Interval: [0.169659591110680736, 0.259013601857933284]. Error: 9.99999678345119364e-10. Poly:
#  poly2[0] = -111918901176566152;
#  poly2[1] = 421997236468903652;
#  poly2[2] = -9508761661583282;
#  poly2[3] = -1127389919352009459;
#  poly2[4] = 999958866368956909;
#
# old [-0.0652096762112879224, -0.0475309723998389042, 0.39760909586456754, -0.00519448450562682688, -1.12772482453226479, 0.999966181674080294]
# new [-65209676211287922, -47530972399838904, 397609095864567540, -5194484505626826, -1127724824532264788, 999966181674080293]
# Interval: [0.259013601857933284, 0.353786078978528071]. Error: 1.6474512656743294e-11. Poly:
#  poly3[0] = -65209676211287922;
#  poly3[1] = -47530972399838904;
#  poly3[2] = 397609095864567540;
#  poly3[3] = -5194484505626826;
#  poly3[4] = -1127724824532264788;
#  poly3[5] = 999966181674080293;
#
# old [-0.172894674851269953, 0.494461858019066163, -0.0427542248887459271, -1.1204184806618389, 0.999396209534647026]
# new [-172894674851269953, 494461858019066163, -42754224888745927, -1120418480661838904, 999396209534647025]
# Interval: [0.353786078978528071, 0.459990490036890169]. Error: 9.9999717630236151e-10. Poly:
#  poly4[0] = -172894674851269953;
#  poly4[1] = 494461858019066163;
#  poly4[2] = -42754224888745927;
#  poly4[3] = -1120418480661838904;
#  poly4[4] = 999396209534647025;
#
# old [0.00303039157950570137, -0.191137674706458748, 0.521142177917722566, -0.0594019809493704713, -1.11561510878280657, 0.998866774328912046]
# new [3030391579505701, -191137674706458748, 521142177917722565, -59401980949370471, -1115615108782806567, 998866774328912046]
# Interval: [0.459990490036890169, 0.610520471007031846]. Error: 2.76811239127432934e-10. Poly:
#  poly5[0] = 3030391579505701;
#  poly5[1] = -191137674706458748;
#  poly5[2] = 521142177917722565;
#  poly5[3] = -59401980949370471;
#  poly5[4] = -1115615108782806567;
#  poly5[5] = 998866774328912046;
#
# old [-0.170158594131959763, 0.480678240807594762, -0.0252701278696922814, -1.12903590802504612, 1.00088876118839166]
# new [-170158594131959763, 480678240807594761, -25270127869692281, -1129035908025046122, 1000888761188391659]
# Interval: [0.610520471007031846, 0.716456553421772003]. Error: 9.99996176633438913e-10. Poly:
#  poly6[0] = -170158594131959763;
#  poly6[1] = 480678240807594761;
#  poly6[2] = -25270127869692281;
#  poly6[3] = -1129035908025046122;
#  poly6[4] = 1000888761188391659;
#
# old [0.0555661428810198343, -0.359055385165369761, 0.737815103777307506, -0.200493977237546773, -1.06925447245321938, 0.992718615091171271]
# new [55566142881019834, -359055385165369760, 737815103777307506, -200493977237546773, -1069254472453219380, 992718615091171271]
# Interval: [0.716456553421772003, 0.814419090105124092]. Error: 1.1072085209794667e-11. Poly:
#  poly7[0] = 55566142881019834;
#  poly7[1] = -359055385165369760;
#  poly7[2] = 737815103777307506;
#  poly7[3] = -200493977237546773;
#  poly7[4] = -1069254472453219380;
#  poly7[5] = 992718615091171271;
#
# old [0.0662635034586825636, -0.40229381951139776, 0.807777341543742118, -0.257140241235805385, -1.04630379468055329, 0.988996167462802833]
# new [66263503458682563, -402293819511397759, 807777341543742118, -257140241235805384, -1046303794680553289, 988996167462802832]
# Interval: [0.814419090105124092, 0.90923714785508884]. Error: 4.56792418539697345e-12. Poly:
#  poly8[0] = 66263503458682563;
#  poly8[1] = -402293819511397759;
#  poly8[2] = 807777341543742118;
#  poly8[3] = -257140241235805384;
#  poly8[4] = -1046303794680553289;
#  poly8[5] = 988996167462802832;
#
# old [0.069709748908741522, -0.417705558249718151, 0.835356742070047717, -0.281826775434845926, -1.03525075320949559, 0.987015808155172196]
# new [69709748908741521, -417705558249718150, 835356742070047716, -281826775434845925, -1035250753209495593, 987015808155172195]
# Interval: [0.90923714785508884, 1.00324905761105539]. Error: 3.2769831876858566e-13. Poly:
#  poly9[0] = 69709748908741521;
#  poly9[1] = -417705558249718150;
#  poly9[2] = 835356742070047716;
#  poly9[3] = -281826775434845925;
#  poly9[4] = -1035250753209495593;
#  poly9[5] = 987015808155172195;
#
# old [-0.0519570695436439226, 0.0679160685929611749, 0.52316051188306038, -1.4573493816038295, 1.07552908615052017]
# new [-51957069543643922, 67916068592961174, 523160511883060380, -1457349381603829495, 1075529086150520169]
# Interval: [1.00324905761105539, 1.09792208107465278]. Error: 9.99998239986162008e-10. Poly:
#  poly10[0] = -51957069543643922;
#  poly10[1] = 67916068592961174;
#  poly10[2] = 523160511883060380;
#  poly10[3] = -1457349381603829495;
#  poly10[4] = 1075529086150520169;
#
# old [-0.0215766886664987532, -0.0654532855153116997, 0.742805742431458269, -1.61818291461204684, 1.11970994054624522]
# new [-21576688666498753, -65453285515311699, 742805742431458268, -1618182914612046835, 1119709940546245218]
# Interval: [1.09792208107465278, 1.19484327053936761]. Error: 9.99998920520876454e-10. Poly:
#  poly11[0] = -21576688666498753;
#  poly11[1] = -65453285515311699;
#  poly11[2] = 742805742431458268;
#  poly11[3] = -1618182914612046835;
#  poly11[4] = 1119709940546245218;
#
# old [0.00499114205677884883, -0.19235076266651453, 0.970177006310468837, -1.79931283153696697, 1.17383901178908414]
# new [4991142056778848, -192350762666514530, 970177006310468836, -1799312831536966970, 1173839011789084140]
# Interval: [1.19484327053936761, 1.2958833596584199]. Error: 9.99997256529116222e-10. Poly:
#  poly12[0] = 4991142056778848;
#  poly12[1] = -192350762666514530;
#  poly12[2] = 970177006310468836;
#  poly12[3] = -1799312831536966970;
#  poly12[4] = 1173839011789084140;
#
# old [0.0339670225221589041, -0.202908361681991884, 0.315866429877815271, 0.350027399540622084, -1.42162941196703093, 1.08201482907518231]
# new [33967022522158904, -202908361681991884, 315866429877815270, 350027399540622083, -1421629411967030929, 1082014829075182305]
# Interval: [1.2958833596584199, 1.40382399792140196]. Error: 1.72436650870406738e-11. Poly:
#  poly13[0] = 33967022522158904;
#  poly13[1] = -202908361681991884;
#  poly13[2] = 315866429877815270;
#  poly13[3] = 350027399540622083;
#  poly13[4] = -1421629411967030929;
#  poly13[5] = 1082014829075182305;
#
# old [0.0414529475614777262, -0.38762484729209878, 1.36309280909816126, -2.15135568339001032, 1.29234786759497332]
# new [41452947561477726, -387624847292098780, 1363092809098161255, -2151355683390010317, 1292347867594973321]
# Interval: [1.40382399792140196, 1.5242938049664262]. Error: 9.99997277277278461e-10. Poly:
#  poly14[0] = 41452947561477726;
#  poly14[1] = -387624847292098780;
#  poly14[2] = 1363092809098161255;
#  poly14[3] = -2151355683390010317;
#  poly14[4] = 1292347867594973321;
#
# old [0.0492688584270668139, -0.435081996210602674, 1.47119023389349598, -2.260829092981613, 1.33393863067852406]
# new [49268858427066813, -435081996210602673, 1471190233893495978, -2260829092981612995, 1333938630678524055]
# Interval: [1.5242938049664262, 1.68290450000348267]. Error: 9.99998730080758514e-10. Poly:
#  poly15[0] = 49268858427066813;
#  poly15[1] = -435081996210602673;
#  poly15[2] = 1471190233893495978;
#  poly15[3] = -2260829092981612995;
#  poly15[4] = 1333938630678524055;
#
# old [0.0478304572854788688, -0.425012909771359169, 1.4447902781491658, -2.23010022658702666, 1.32053968582038817]
# new [47830457285478868, -425012909771359169, 1444790278149165795, -2230100226587026655, 1320539685820388168]
# Interval: [1.68290450000348267, 1.82965326824274199]. Error: 9.99997887784715181e-10. Poly:
#  poly16[0] = 47830457285478868;
#  poly16[1] = -425012909771359169;
#  poly16[2] = 1444790278149165795;
#  poly16[3] = -2230100226587026655;
#  poly16[4] = 1320539685820388168;
#
# old [-0.0119108914204796562, 0.15392328137202855, -0.803122082486271689, 2.11878267140172146, -2.83100624288042804, 1.53491222025439544]
# new [-11910891420479656, 153923281372028550, -803122082486271688, 2118782671401721458, -2831006242880428044, 1534912220254395438]
# Interval: [1.82965326824274199, 1.96304764938219344]. Error: 1.01021270653857858e-11. Poly:
#  poly17[0] = -11910891420479656;
#  poly17[1] = 153923281372028550;
#  poly17[2] = -803122082486271688;
#  poly17[3] = 2118782671401721458;
#  poly17[4] = -2831006242880428044;
#  poly17[5] = 1534912220254395438;
#
# old [-0.013092298487596493, 0.165366593717155453, -0.847463753441230523, 2.20470211694293697, -2.91425753062440093, 1.56718240812463783]
# new [-13092298487596492, 165366593717155452, -847463753441230523, 2204702116942936969, -2914257530624400926, 1567182408124637827]
# Interval: [1.96304764938219344, 2.09439277873524649]. Error: 9.14208121798046278e-13. Poly:
#  poly18[0] = -13092298487596492;
#  poly18[1] = 165366593717155452;
#  poly18[2] = -847463753441230523;
#  poly18[3] = 2204702116942936969;
#  poly18[4] = -2914257530624400926;
#  poly18[5] = 1567182408124637827;
#
# old [-0.0120442029415170727, 0.154302455874269273, -0.800737262666187783, 2.10601811887340516, -2.81003362232668283, 1.52314577963249886]
# new [-12044202941517072, 154302455874269273, -800737262666187783, 2106018118873405156, -2810033622326682830, 1523145779632498862]
# Interval: [2.09439277873524649, 2.22769987396574029]. Error: 6.38171541478864999e-12. Poly:
#  poly19[0] = -12044202941517072;
#  poly19[1] = 154302455874269273;
#  poly19[2] = -800737262666187783;
#  poly19[3] = 2106018118873405156;
#  poly19[4] = -2810033622326682830;
#  poly19[5] = 1523145779632498862;
#
# old [0.0166935724013738205, -0.171805681808169426, 0.668689413756477279, -1.16754686285113722, 0.772339093787630402]
# new [16693572401373820, -171805681808169426, 668689413756477278, -1167546862851137224, 772339093787630402]
# Interval: [2.22769987396574029, 2.36638162683588504]. Error: 9.99999588640869628e-10. Poly:
#  poly20[0] = 16693572401373820;
#  poly20[1] = -171805681808169426;
#  poly20[2] = 668689413756477278;
#  poly20[3] = -1167546862851137224;
#  poly20[4] = 772339093787630402;
#
# old [-0.00716330296026200814, 0.098029234739114877, -0.54094293757029578, 1.50568742611081699, -2.11567989610840552, 1.20156800139507302]
# new [-7163302960262008, 98029234739114877, -540942937570295779, 1505687426110816992, -2115679896108405521, 1201568001395073017]
# Interval: [2.36638162683588504, 2.51384517270022168]. Error: 1.51339511033721228e-11. Poly:
#  poly21[0] = -7163302960262008;
#  poly21[1] = 98029234739114877;
#  poly21[2] = -540942937570295779;
#  poly21[3] = 1505687426110816992;
#  poly21[4] = -2115679896108405521;
#  poly21[5] = 1201568001395073017;
#
# old [-0.00465473000163957662, 0.066496111784487004, -0.382358193099718664, 1.1068278369622102, -1.61398134123091057, 0.949092201108683911]
# new [-4654730001639576, 66496111784487003, -382358193099718664, 1106827836962210199, -1613981341230910569, 949092201108683911]
# Interval: [2.51384517270022168, 2.67431518253944485]. Error: 2.0325565346218359e-11. Poly:
#  poly22[0] = -4654730001639576;
#  poly22[1] = 66496111784487003;
#  poly22[2] = -382358193099718664;
#  poly22[3] = 1106827836962210199;
#  poly22[4] = -1613981341230910569;
#  poly22[5] = 949092201108683911;
#
# old [0.0030849287948971012, -0.0367166533524701707, 0.164547038290303311, -0.329213390297632233, 0.248210701723242406]
# new [3084928794897101, -36716653352470170, 164547038290303310, -329213390297632232, 248210701723242406]
# Interval: [2.67431518253944485, 2.8538614241020888]. Error: 9.99998769493563294e-10. Poly:
#  poly23[0] = 3084928794897101;
#  poly23[1] = -36716653352470170;
#  poly23[2] = 164547038290303310;
#  poly23[3] = -329213390297632232;
#  poly23[4] = 248210701723242406;
#
# old [-0.00122405116177181684, 0.0193962025451939508, -0.123377887093972916, 0.393917669673378263, -0.631491475223548449, 0.406792466769060236]
# new [-1224051161771816, 19396202545193950, -123377887093972916, 393917669673378262, -631491475223548448, 406792466769060236]
# Interval: [2.8538614241020888, 3.0623839829272568]. Error: 3.62085162227876069e-11. Poly:
#  poly24[0] = -1224051161771816;
#  poly24[1] = 19396202545193950;
#  poly24[2] = -123377887093972916;
#  poly24[3] = 393917669673378262;
#  poly24[4] = -631491475223548448;
#  poly24[5] = 406792466769060236;
#
# old [0.000402370982600247803, -0.00542008568113698826, 0.0274398310661225944, -0.0618897208254327464, 0.052482974671370607]
# new [402370982600247, -5420085681136988, 27439831066122594, -61889720825432746, 52482974671370607]
# Interval: [3.0623839829272568, 3.31855890615527227]. Error: 9.99999661345919411e-10. Poly:
#  poly25[0] = 402370982600247;
#  poly25[1] = -5420085681136988;
#  poly25[2] = 27439831066122594;
#  poly25[3] = -61889720825432746;
#  poly25[4] = 52482974671370607;
#
# old [0.0000740242969025806073, -0.00108179835565496972, 0.00593689700826588404, -0.014502731665446309, 0.0133071492101725627]
# new [74024296902580, -1081798355654969, 5936897008265884, -14502731665446309, 13307149210172562]
# Interval: [3.31855890615527227, 3.6661363549300592]. Error: 9.99999144837340039e-10. Poly:
#  poly26[0] = 74024296902580;
#  poly26[1] = -1081798355654969;
#  poly26[2] = 5936897008265884;
#  poly26[3] = -14502731665446309;
#  poly26[4] = 13307149210172562;
#
# old [-5.1561834844202477e-6, 0.00010610701434438515, -0.000873922083873472769, 0.00360123940085076646, -0.00742526463805622187, 0.0061287932311796524]
# new [-5156183484420, 106107014344385, -873922083873472, 3601239400850766, -7425264638056221, 6128793231179652]
# Interval: [3.6661363549300592, 4.26359610059707386]. Error: 1.59559341922233318e-10. Poly:
#  poly27[0] = -5156183484420;
#  poly27[1] = 106107014344385;
#  poly27[2] = -873922083873472;
#  poly27[3] = 3601239400850766;
#  poly27[4] = -7425264638056221;
#  poly27[5] = 6128793231179652;
#
# old [1.10950764368129559e-13]
# new [110950]
# Interval: [4.26359610059707386, 6.24]. Error: 1.10949666758802772e-13. Poly:
#  poly28[0] = 110950;

# %%
def ChebErfc(x):
  assert(mpf("0")<=x<=mpf("6.24"))
  for i in intervals:
    start, end, (err, poly) = i
    if(start<=x<=end):
      # erfc(x) can be approximated by this poly
      return polyval(poly, x)

# %%
def evm_hex(x):
  #return x
  if x>=0:
    return hex(x)
  return hex(int("0xffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff", 16)+x+1)

# %%
for i in range(len(ends)-1):
  assert ends[i]<ends[i+1]

def polyvalOpcodes(poly):
  n = len(poly)

  wadN = n-1
  s = "[WAD] "*wadN+f"{evm_hex(poly[0])} "
  for i in range(len(poly)-1):
    s = s + f"dup{2+wadN-i} mul sdiv {evm_hex(poly[i+1])} add "
  s = s + "polyval_end jump"
  return s

def getPolyByIntervalEnd(intervals, v: int):
  for i in range(len(intervals)):
    start, end, (err, poly) = intervals[i]
    if end==v:
      return poly

def printBisectTree(a, start, end, depth, was_to_left, hist, intervals):
  if(was_to_left):
    print('pivot'+hist+':')

  if start+2>=end:
    #print(f"interval end value = {a[end-1]}")
    print(polyvalOpcodes(getPolyByIntervalEnd(intervals, a[end-1])))
    return

  mid = (start+end)//2

  print(evm_hex(a[mid]), 'dup2 lt pivot'+hist+'0', 'jumpi')

  printBisectTree(a,mid,end,depth+1, False, hist+'1', intervals)
  printBisectTree(a, start, mid+1, depth+1, True, hist+'0', intervals)

# %%
print("Huff binary search & poly evaluation code:")
printBisectTree([0]+ends, 0, len(ends)+1, 0, False, '', intervals)
# Out:
# Huff binary search & poly evaluation code:
# 0x15276123ba5a365c dup2 lt pivot0 jumpi
# 0x22e2f8dd9b2090f1 dup2 lt pivot10 jumpi
# 0x2e0de3be1f98084c dup2 lt pivot110 jumpi
# 0x3b2b561061d447bf dup2 lt pivot1110 jumpi
# 0x1b166 polyval_end jump
# pivot1110:
# 0x32e0bb973dc067bf dup2 lt pivot11100 jumpi
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xfffffffffffffffffffffffffffffffffffffffffffffffffffffb4f7b83d7fc dup7 mul sdiv 0x6080f6e5eec1 add dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffffce52c28a11d40 add dup5 mul sdiv 0xccb4ee33d254e add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffffe59ec2dae2a8e3 add dup3 mul sdiv 0x15c61adf723f84 add polyval_end jump
# pivot11100:
# [WAD] [WAD] [WAD] [WAD] 0x43531febefb4 dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffffc281c314ae6c7 add dup5 mul sdiv 0x1517938d3eea9c add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffffcc79d7a6ceea5b add dup3 mul sdiv 0x2f46c81da53c92 add polyval_end jump
# pivot110:
# 0x279af3d845cba062 dup2 lt pivot1100 jumpi
# 0x2a7fc601dc399ce2 dup2 lt pivot11010 jumpi
# [WAD] [WAD] [WAD] [WAD] 0x16df44b7c5e37 dup6 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffffecbe75f652daa4 add dup5 mul sdiv 0x617c6187649962 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffff241fa076f3b556 add dup3 mul sdiv 0xba74fcc60af96f add polyval_end jump
# pivot11010:
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xfffffffffffffffffffffffffffffffffffffffffffffffffffba6bb6150d0d8 dup7 mul sdiv 0x44e8be52b2a3de add dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffe49ac7722a0204c add dup5 mul sdiv 0x5777a0893a1a1d6 add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff73c7dd95c9cede0 add dup3 mul sdiv 0x5a53797df13218c add polyval_end jump
# pivot1100:
# 0x251d137d48b2926f dup2 lt pivot11000 jumpi
# [WAD] [WAD] [WAD] [WAD] 0xaf5b9f4fa2acd dup6 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffff7d8e65f795b966 add dup5 mul sdiv 0x24896a8d622d94e add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffb6e662a7001f218 add dup3 mul sdiv 0x371d25171aa0fa6 add polyval_end jump
# pivot11000:
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xffffffffffffffffffffffffffffffffffffffffffffffffffef768c37ba1768 dup7 mul sdiv 0xec3ddc81dbe85b add dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffab1973fcb54bff8 add dup5 mul sdiv 0xf5c3e0db1a58197 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffe999fc8579d2b397 add dup3 mul sdiv 0xd2bda54122d3c87 add polyval_end jump
# pivot10:
# 0x1d10c722bca85c97 dup2 lt pivot100 jumpi
# 0x20d7138d4e905bf1 dup2 lt pivot1010 jumpi
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xffffffffffffffffffffffffffffffffffffffffffffffffffe68d038fa29488 dup7 mul sdiv 0x15c4511d23a737d add dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff87e2f43aa5dc01d add dup5 mul sdiv 0x14e546bc901b82e0 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffe2a398580605ecef add dup3 mul sdiv 0x10acd3bb28a11ff9 add polyval_end jump
# pivot1010:
# 0x1eea613b85e91106 dup2 lt pivot10100 jumpi
# [WAD] [WAD] [WAD] [WAD] 0x3b4eb73504227c dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffd9d9fa4856e262e add dup5 mul sdiv 0x947a97a9c04df5e add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffefcc0a506d22e138 add dup3 mul sdiv 0xab7e650535bdb42 add polyval_end jump
# pivot10100:
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xffffffffffffffffffffffffffffffffffffffffffffffffffd535dc7a1172f0 dup7 mul sdiv 0x22431441e5b3059 add dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff4e335b3bc5cfbf9 add dup5 mul sdiv 0x1d3a145229fc56e4 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffd900c14f06505b32 add dup3 mul sdiv 0x15234d04402168ae add polyval_end jump
# pivot100:
# 0x19643bf41bbdbaea dup2 lt pivot1000 jumpi
# 0x1b3e256fba97591e dup2 lt pivot10010 jumpi
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xffffffffffffffffffffffffffffffffffffffffffffffffffd17c9fb75a7a34 dup7 mul sdiv 0x24b800a743a367c add dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff43d3434d01dc145 add dup5 mul sdiv 0x1e98ace4f3ef7b89 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffd78e7a375f2021e2 add dup3 mul sdiv 0x15bfc018ce82a283 add polyval_end jump
# pivot10010:
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xffffffffffffffffffffffffffffffffffffffffffffffffffd5af1b7bec8f58 dup7 mul sdiv 0x222d868acd79e86 add dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff4dabcb89a224138 add dup5 mul sdiv 0x1d676d9d25271e72 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffd8b63ed24832e7f4 add dup3 mul sdiv 0x154d1a8831ab5c2e add polyval_end jump
# pivot1000:
# 0x175ae0b9f19d2c29 dup2 lt pivot10000 jumpi
# [WAD] [WAD] [WAD] [WAD] 0xa9ed8c27f209d4 dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffa1a0d02a81f7c3f add dup5 mul sdiv 0x140ced1a6804d2e3 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffe10d17a8d4c31b21 add dup3 mul sdiv 0x12537fd905215348 add polyval_end jump
# pivot10000:
# [WAD] [WAD] [WAD] [WAD] 0xaf09c40508c9bd dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff9f6473ac7b2fd4f add dup5 mul sdiv 0x146ab7b9183ee4aa add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffe09febeb16f65e3d add dup3 mul sdiv 0x12831a1df9c3b097 add polyval_end jump
# pivot0:
# 0xb4d65d8f40344fc dup2 lt pivot00 jumpi
# 0x1094ef9fbec3d4b6 dup2 lt pivot010 jumpi
# 0x137b627d03461c6c dup2 lt pivot0110 jumpi
# [WAD] [WAD] [WAD] [WAD] 0x93453c764b765e dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffa9ee1414f0a1724 add dup5 mul sdiv 0x12eaadb01a2f6c67 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffe224d96782054c33 add dup3 mul sdiv 0x11ef5789d63b6089 add polyval_end jump
# pivot0110:
# 0x11fbe70cbac7a6c0 dup2 lt pivot01100 jumpi
# [WAD] [WAD] [WAD] [WAD] [WAD] 0x78acd3b782cf38 dup7 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffd2f1feb8bfd0734 add dup6 mul sdiv 0x4622ed82d5687e6 add dup5 mul sdiv 0x4db8c10bb45c303 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffec455b94f975296f add dup3 mul sdiv 0xf0416c118bb32e1 add polyval_end jump
# pivot01100:
# [WAD] [WAD] [WAD] [WAD] 0x11bb6ad1515c60 dup6 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffd54a2001efca79e add dup5 mul sdiv 0xd76c2d8d6632ce4 add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffe7078e834c6fd2c6 add dup3 mul sdiv 0x104a505ca92f15ec add polyval_end jump
# pivot010:
# 0xdec41b3d427011e dup2 lt pivot0100 jumpi
# 0xf3c9a50d183266f dup2 lt pivot01010 jumpi
# [WAD] [WAD] [WAD] [WAD] 0xffffffffffffffffffffffffffffffffffffffffffffffffffb3581db09aa93f dup6 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffff177695677a45ad add dup5 mul sdiv 0xa4ef9e31ebf53dc add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffe98b0f3670f1540d add dup3 mul sdiv 0xf8a024229bb9262 add polyval_end jump
# pivot01010:
# [WAD] [WAD] [WAD] [WAD] 0xffffffffffffffffffffffffffffffffffffffffffffffffff4769520e47e4ee dup6 mul sdiv 0xf1494df7064696 add dup5 mul sdiv 0x742a3b6b74d249c add dup4 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffebc6747573de5909 add dup3 mul sdiv 0xeed0c01659a2d69 add polyval_end jump
# pivot0100:
# 0xc9e425e5e7decc8 dup2 lt pivot01000 jumpi
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xf7a8a5b5165391 dup7 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffa34030203d1be7a add dup6 mul sdiv 0xb97c887efd013e4 add dup5 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffc16c00a7a03211b add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff1a20cecc97e0fd7 add dup3 mul sdiv 0xdb295a5e8c8bd63 add polyval_end jump
# pivot01000:
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xeb6a4e293a46c3 dup7 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffa6ac3e710b02281 add dup6 mul sdiv 0xb35cd365c52faa6 add dup5 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffc6e74501fae7b38 add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff17ac83e06ec20b7 add dup3 mul sdiv 0xdb99ec63dd7d590 add polyval_end jump
# pivot00:
# 0x4e8e6907bfe5347 dup2 lt pivot000 jumpi
# 0x87901223a7a7226 dup2 lt pivot0010 jumpi
# 0x9f15d707bb494e3 dup2 lt pivot00110 jumpi
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xc5691ccff637ba dup7 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffb0461079086ee60 add dup6 mul sdiv 0xa3d3eed82907b72 add dup5 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffd37b3ca3b2698eb add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff1293eb8f2ed9bcc add dup3 mul sdiv 0xdc6d8521e6d4fc7 add polyval_end jump
# pivot00110:
# [WAD] [WAD] [WAD] [WAD] 0xfffffffffffffffffffffffffffffffffffffffffffffffffda379a90148e02d dup6 mul sdiv 0x6abb6503298ab09 add dup5 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffffa638f3dce5f687 add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff054dbd2d381ab96 add dup3 mul sdiv 0xde3df067e509aeb add polyval_end jump
# pivot0010:
# 0x66236e9deb4ea38 dup2 lt pivot00100 jumpi
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xac42005a07425 dup7 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffd58f14c2bed6784 add dup6 mul sdiv 0x73b780cb8425fc5 add dup5 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffff2cf6368a8ee999 add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff08489f826f129d9 add dup3 mul sdiv 0xddcb009fdd0a8ae add polyval_end jump
# pivot00100:
# [WAD] [WAD] [WAD] [WAD] 0xfffffffffffffffffffffffffffffffffffffffffffffffffd99c13591eef2bf dup6 mul sdiv 0x6dcae70aa34c133 add dup5 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffff681b424cdbf039 add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff0737953fc5e43c8 add dup3 mul sdiv 0xdde918ebb2f3af1 add polyval_end jump
# pivot000:
# 0x25ac07fcce3e0a0 dup2 lt pivot0000 jumpi
# 0x398337fa2bc8fe3 dup2 lt pivot00010 jumpi
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xffffffffffffffffffffffffffffffffffffffffffffffffff1854251d82088e dup7 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffff5722d51a475948 add dup6 mul sdiv 0x584975db678c6f4 add dup5 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffffed8ba4d4403736 add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff059843f3d5d58ac add dup3 mul sdiv 0xde097f1b6165825 add polyval_end jump
# pivot00010:
# [WAD] [WAD] [WAD] [WAD] 0xfffffffffffffffffffffffffffffffffffffffffffffffffe72625a33b7fe78 dup6 mul sdiv 0x5db3c402feceee4 add dup5 mul sdiv 0xffffffffffffffffffffffffffffffffffffffffffffffffffde37d4e6e8504e add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff05ab4d76daacd0d add dup3 mul sdiv 0xde0914a7bec89ed add polyval_end jump
# pivot0000:
# 0x128ab9b8a399fb0 dup2 lt pivot00000 jumpi
# [WAD] [WAD] [WAD] [WAD] 0xffffffffffffffffffffffffffffffffffffffffffffffffff0af4edc0234654 dup6 mul sdiv 0x5740b06ac99882e add dup5 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffffff8c19eb90ddcaf add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff057a1d0ce381f22 add dup3 mul sdiv 0xde0b3e99287f50c add polyval_end jump
# pivot00000:
# [WAD] [WAD] [WAD] [WAD] [WAD] 0xfffffffffffffffffffffffffffffffffffffffffffffffffe4542bb968b8933 dup7 mul sdiv 0x15226fd7e2307a add dup6 mul sdiv 0x53391114286721f add dup5 mul sdiv 0x8a32eeef924d add dup4 mul sdiv 0xfffffffffffffffffffffffffffffffffffffffffffffffff0572aa2e9171b0c add dup3 mul sdiv 0xde0b6baa3168cc3 add polyval_end jump
